# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Pie Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# - In this lab, you will focus on visualizing data.
#
# - The provided dataset will be loaded into pandas for analysis.
#
# - Various pie charts will be created to:
#    - Analyze developer preferences.
#
#    - Identify technology usage trends.
#
# - The lab aims to provide insights into key variables using visual representations.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# ## Setup: Downloading and Loading the Data
# **Install the libraries**

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 125.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 151.5 MB/s eta 0:00:00
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 152.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 143.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 161.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Download and Load the Data**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Out:
# --2026-07-08 13:16:12--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  43.7MB/s    in 4.3s
#
# 2026-07-08 13:16:16 (35.7 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]

# %%
# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Composition with Pie Charts

# %% [markdown]
# ##### 1.1 Create a Pie Chart of the Top 5 Databases Respondents Want to Work With

# %% [markdown]
# In the survey data, the `DatabaseWantToWorkWith` column lists the databases that respondents wish to work with. Let’s visualize the top 5 most-desired databases in a pie chart.

# %%
##Write your code here
df=df.dropna(subset=['DatabaseWantToWorkWith'])
gr_data=df.groupby(['DatabaseWantToWorkWith']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head()
plt.pie(pie_data['Count'],labels=pie_data['DatabaseWantToWorkWith'],autopct='%1.1f%%',explode=(0,0,0,0,0.05))
plt.title('Top 5 Databases Respondents Want to Work With')
plt.show()

# %% [markdown]
# The `DevType` column lists the developer types for respondents. We’ll examine the distribution by showing the top 5 developer roles in a pie chart.

# %%
##Write your code here
df=df.dropna(subset=['DevType'])
gr_data=df.groupby(['DevType']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head()
plt.pie(pie_data['Count'],labels=pie_data['DevType'],autopct='%1.1f%%',explode=(0,0,0,0,0.08),shadow=True,wedgeprops={'edgecolor':'black'})
plt.title('Pie chart showing the distribution of top 5 developer roles')
plt.show()

# %% [markdown]
# ##### 1.3 Create a pie chart for the operating systems used by respondents for professional use

# %% [markdown]
# The `OpSysProfessional` use column shows the operating systems developers use professionally. Let’s visualize the distribution of the top operating systems in a pie chart.

# %%
##Write your code here
df=df.dropna(subset=['OpSysProfessional use'])
gr_data=df.groupby(['OpSysProfessional use']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head(3)
plt.pie(pie_data['Count'],labels=pie_data['OpSysProfessional use'],autopct='%1.1f%%',explode=(0,0,0.05),shadow=True,wedgeprops={'edgecolor':'white'})
plt.title('Top Operating system Respondents use professionally')
plt.show()

# %% [markdown]
# ### Task 2: Additional Visualizations and Comparisons

# %% [markdown]
# ##### 2.1 Pie Chart for Top 5 Programming Languages Respondents Have Worked With

# %% [markdown]
# The `LanguageHaveWorkedWith` column contains the programming languages that respondents have experience with. We’ll plot a pie chart to display the composition of the top 5 languages.

# %%
##Write your code here
df=df.dropna(subset=['LanguageHaveWorkedWith'])
df['LanguageHaveWorkedWith']=df['LanguageHaveWorkedWith'].str.split(';')
df=df.explode('LanguageHaveWorkedWith')
gr_data=df.groupby(['LanguageHaveWorkedWith']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head()
plt.pie(pie_data['Count'],labels=pie_data['LanguageHaveWorkedWith'],autopct='%1.1f%%',explode=(0,0,0,0,0.1),shadow=True,wedgeprops={'edgecolor':'white'})
plt.title('Top 5 Programming Languages Respondents Have Worked With')
plt.show()

# %% [markdown]
# ##### 2.2 Pie Chart for Top Collaboration Tools used in Professional Use

# %% [markdown]
# Using the `NEWCollabToolsHaveWorkedWith` column, we’ll identify and visualize the top collaboration tools respondents use in their professional work.

# %%
##Write your code here
df=df.dropna(subset=['NEWCollabToolsHaveWorkedWith'])
df['NEWCollabToolsHaveWorkedWith']=df['NEWCollabToolsHaveWorkedWith'].str.split(';')
df=df.explode('NEWCollabToolsHaveWorkedWith')
gr_data=df.groupby(['NEWCollabToolsHaveWorkedWith']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head()
plt.pie(pie_data['Count'],labels=pie_data['NEWCollabToolsHaveWorkedWith'],autopct='%1.1f%%',explode=(0,0,0,0,0.1),colors=['steelblue','lightblue','lime','cyan','orange'],shadow=True,wedgeprops={'edgecolor':'white'})
plt.title('Top Collaboration Tools used in Professional Use')
plt.show()

# %% [markdown]
# ### Task 3: Analyzing and Interpreting Composition

# %% [markdown]
# In this task, you will create additional pie charts to analyze specific aspects of the survey data. Use `pandas` and `matplotlib` to complete each task and interpret the findings.

# %% [markdown]
# ##### 3.1 Pie Chart of `Respondents` Most Admired Programming Languages

# %% [markdown]
# The `LanguageAdmired` column lists the programming languages respondents admire most. Create a pie chart to visualize the top 5 admired languages.

# %%
##Write your code here
df=df.dropna(subset=['LanguageAdmired'])
df['LanguageAdmired']=df['LanguageAdmired'].str.split(';')
df=df.explode('LanguageAdmired')
gr_data=df.groupby(['LanguageAdmired']).size().reset_index(name='Count')
gr_data=gr_data.sort_values(by='Count',ascending=False)
pie_data=gr_data.head()
plt.pie(pie_data['Count'],labels=pie_data['LanguageAdmired'],explode=(0,0,0,0,0.08),autopct='%1.1f%%',colors=['lightgreen','lightblue','steelblue','cyan','orange'],shadow=True,wedgeprops={'edgecolor':'white'})
plt.title('Top 5 programming languages respondents admire most')
plt.show()

# %% [markdown]
# ##### 3.2 Pie Chart of Tools Used for AI Development

# %% [markdown]
# Using the `AIToolCurrently` Using column, create a pie chart to visualize the top 5 tools developers are currently using for AI development.

# %%
##Write your code here
df=df.dropna(subset=['AIToolCurrently Using'])
gr_data=df['AIToolCurrently Using'].str.split(';').explode().value_counts()
pie_data=gr_data.head()
plt.pie(pie_data,labels=pie_data.index,explode=(0,0,0,0,0.08),autopct='%1.1f%%',shadow=True,wedgeprops={'edgecolor':'white'})
plt.title(' Top 5 tools developers are currently using for AI development')
plt.show()

# %% [markdown]
# ##### 3.3 Pie Chart for Preferred Web Frameworks

# %% [markdown]
# The `WebframeWantToWorkWith` column includes web frameworks that respondents are interested in working with. Visualize the top 5 frameworks in a pie chart.

# %%
##Write your code here
df=df.dropna(subset=['WebframeWantToWorkWith'])
gr_data=df['WebframeWantToWorkWith'].str.split(';').explode().value_counts()
pie_data=gr_data.head()
plt.pie(pie_data,labels=pie_data.index,explode=(0,0,0,0,0.08),autopct='%1.1f%%',colors=['steelblue','lightgreen','lightblue','lightcoral','orange'],shadow=True,wedgeprops={'edgecolor':'white'})
plt.title(' Top 5 web frameworks that respondents are interested in working with')
plt.show()

# %% [markdown]
# ##### 3.4 Pie Chart for Most Desired Embedded Technologies

# %% [markdown]
# Using the `EmbeddedWantToWorkWith` column, create a pie chart to show the top 5 most desired embedded technologies that respondents wish to work with.

# %%
##Write your code here
df=df.dropna(subset=['EmbeddedWantToWorkWith'])
gr_data=df['EmbeddedWantToWorkWith'].str.split(';').explode().value_counts()
pie_data=gr_data.head()
plt.pie(pie_data,labels=pie_data.index,explode=(0,0,0,0,0.08),autopct='%1.1f%%',colors=['orchid','lightgreen','lightblue','lightcoral','gold'],shadow=True,wedgeprops={'edgecolor':'white'})
plt.title('Top 5 most desired embedded technologies that respondents wish to work with')
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create pie charts to visualize developer preferences across databases, programming languages, AI tools, and cloud platforms.
# - Identify trends in technology usage, role distribution, and tool adoption through pie charts.
# - Analyze and compare data composition across various categories to gain insights into developer preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
